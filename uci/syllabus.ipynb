# %% [markdown]
# # Go Leetcode
# by UCI

# %% [markdown]
# ### 2018 Summer Syllabus

# %%
import pandas as pd

# %%
def hyperlink(val):
    return '<a href="%s">%s</a>' % (val, val) if pd.notnull(val) else ""

# %%
pd.set_option('max_colwidth',500)
df = pd.read_csv('syllabus.csv', index_col=0)
df.style.format(hyperlink)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_f7a949e2_36ed_11e9_98ee_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Required-1</th>
#         <th class="col_heading level0 col1" >Required-2</th>
#         <th class="col_heading level0 col2" >Required-3</th>
#         <th class="col_heading level0 col3" >Optional</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f7a949e2_36ed_11e9_98ee_acde48001122level0_row0" class="row_heading level0 row0" >Warm Up</th>
#         <td id="T_f7a949e2_36ed_11e9_98ee_acde48001122row0_col0" class="data row0 col0" ><a href="https://leetcode.com/problems/pascals-triangle-ii/description/">https://leetcode.com/problems/pascals-triangle-ii/description/</a></td>
#         <td id="T_f7a949e2_36ed_11e9_98ee_acde48001122row0_col1" class="data row0 col1" ><a href="https://leetcode.com/problems/ugly-number-ii">https://leetcode.com/problems/ugly-number-ii</a></td>
# ...
