# %% [markdown]
# # Go Leetcode
# by UCI

# %% [markdown]
# ### 2018 Summer Syllabus

# %%
import pandas as pd

# %%
df = pd.read_csv('syllabus.csv', index_col=0)
df.fillna('')
# Out:
#                                                 Required-1  \
# Warm Up  https://leetcode.com/problems/pascals-triangle...
# E0       https://leetcode.com/problems/word-break/descr...
# E1       https://leetcode.com/problems/reverse-bits/des...
# E2       https://leetcode.com/problems/house-robber/des...
# E3       https://leetcode.com/problems/best-time-to-buy...
# E4       https://leetcode.com/problems/number-of-island...
# E5       https://leetcode.com/problems/permutations-ii/...
# E6       https://leetcode.com/problems/maximum-binary-t...
# E7       https://leetcode.com/problems/longest-substrin...
# E8       https://leetcode.com/problems/battleships-in-a...
# E9       https://leetcode.com/problems/min-stack/descri...
# E10      https://leetcode.com/problems/n-queens/descrip...
# E11      https://leetcode.com/problems/two-sum/descript...
# E12      https://leetcode.com/problems/island-perimeter...
# E13      https://leetcode.com/problems/reverse-linked-l...
# ...
